# %%
import re
import json
import time

def extract_json_from_text(text):
    json_pattern = r'{(?:[^{}]|(?R))*}'
    
    try:
        # Find all potential JSON matches
        matches = re.finditer(json_pattern, text)
        extracted = []
        
        for match in matches:
            try:
                # Try to parse each match as JSON
                json_str = match.group()
                json_obj = json.loads(json_str)
                extracted.append(json_obj)
            except json.JSONDecodeError:
                continue
        
        return extracted
    except Exception as e:
        return f"Error extracting JSON: {str(e)}"

# %%
import pandas as pd

df = pd.read_csv("exercise_inventory - exercises.csv")
df.head(2)
# Out:
#                exercise_name muscle_group  \
# 0               Assisted Dip        Chest
# 1  Band-Assisted Bench Press        Chest
#
#                                   exercise_image_url  \
# 0  https://i0.wp.com/www.strengthlog.com/wp-conte...
# 1  https://i0.wp.com/www.strengthlog.com/wp-conte...
#
#                                 muscles_worked_image  \
# 0  https://i0.wp.com/www.strengthlog.com/wp-conte...
# 1  https://i0.wp.com/www.strengthlog.com/wp-conte...
#
#                                           commentary  \
# 0  Assisted dips are a good alternative if the di...
# 1  The bench press against bands is a variation o...
#
#                                             page_url
# 0         https://www.strengthlog.com/assisted-dips/
# 1  https://www.strengthlog.com/band-assisted-benc...

# %%
SYSTEM_PROMPT = '''
Return weight ranges in pounds for {EXERCISE NAME} for three skill levels in JSON format. Use these examples as reference for format:

Examples:

Input: Bench Press
Output:
{
    "exercise_weights": {
        "level1": {"min": 45, "max": 135},
        "level2": {"min": 135, "max": 225},
        "level3": {"min": 225, "max": 315}
    }
}

Input: Deadlift
Output:
{
    "exercise_weights": {
        "level1": {"min": 95, "max": 185},
        "level2": {"min": 185, "max": 315},
        "level3": {"min": 315, "max": 405}
    }
}

Input: Bicep Curl
Output:
{
    "exercise_weights": {
        "level1": {"min": 10, "max": 20},
        "level2": {"min": 20, "max": 40},
        "level3": {"min": 40, "max": 65}
    }
}

Level 1 is for beginners, level 2 for intermediate lifters, and level 3 for advanced lifters. 
Now give me the weight ranges for: {EXERCISE NAME}
Return only the JSON, no additional text."
'''

# %%
from typing_extensions import TypedDict

class ExerciseWeightRange(TypedDict):
    min: int
    max: int

class ExerciseLevels(TypedDict):
    level1: ExerciseWeightRange
    level2: ExerciseWeightRange
    level3: ExerciseWeightRange

class ExerciseMatchResponse(TypedDict):
    """Schema for exercise weight ranges response"""
    exercise_weights: ExerciseLevels

# %%
import google.generativeai as genai

def get_json_for_exercise(exercise:str):
    genai.configure(api_key="AIzaSyDVRperfr8bQ8H0FhoRVDDQlSvEek_V_2U")
    model = genai.GenerativeModel("gemini-2.0-flash-exp",system_instruction=SYSTEM_PROMPT)

    result = model.generate_content(
        exercise
    )

    res = result.text
    s = res.find('{')
    e = res.rfind('}')
    if e == len(res)-1:
        json_res = json.loads(res[s:])
    else:
        json_res = json.loads(res[s:e+1])
    return {exercise:json_res}

# %%
exercise_list = df['exercise_name'].to_list()

# %%
try:
    with open('exercise_range.json', 'r') as f:
        existing_data = json.load(f)
except (FileNotFoundError, json.JSONDecodeError):
    existing_data = {}

last_idx = 16
# Process each exercise
for idx,exercise in enumerate(exercise_list[last_idx:]):
    res_json = get_json_for_exercise(exercise)
    existing_data.update(res_json)
    
    # Save after each update to prevent data loss
    with open('exercise_range.json', 'w') as f:
        json.dump(existing_data, f, indent=4)
    print(f"{idx+last_idx}--->{exercise}")
    time.sleep(6)
# Out:
# 16--->Feet-Up Bench Press
# 17--->Floor Press
# 18--->Incline Bench Press
# 19--->Incline Dumbbell Press
# 20--->Incline Push-Up
# 21--->Kettlebell Floor Press
# 22--->Kneeling Incline Push-Up
# 23--->Kneeling Push-Up
# 24--->Machine Chest Fly
# 25--->Machine Chest Press
# 26--->Pec Deck
# 27--->Pin Bench Press
# 28--->Push-Up
# 29--->Push-Up Against Wall
# 30--->Push-Ups With Feet in Rings
# 31--->Resistance Band Chest Fly
# 32--->Ring Dip
# 33--->Smith Machine Bench Press
# 34--->Smith Machine Incline Bench Press
# 35--->Smith Machine Reverse Grip Bench Press
# 36--->Standing Cable Chest Fly
# 37--->Standing Resistance Band Chest Fly
# 38--->Arnold Press
# 39--->Band External Shoulder Rotation
# 40--->Band Internal Shoulder Rotation
# 41--->Band Pull-Apart
# 42--->Barbell Front Raise
# 43--->Barbell Rear Delt Row
# 44--->Barbell Upright Row
# 45--->Behind the Neck Press
# 46--->Cable Lateral Raise
# 47--->Cable Rear Delt Row
# 48--->Cuban Press
# 49--->Dumbbell Front Raise
# 50--->Dumbbell Horizontal Internal Shoulder Rotation
# 51--->Dumbbell Horizontal External Shoulder Rotation
# 52--->Dumbbell Lateral Raise
# 53--->Dumbbell Rear Delt Row
# 54--->Dumbbell Shoulder Press
# 55--->Face Pull
# 56--->Front Hold
# 57--->Landmine Press
# 58--->Lying Dumbbell External Shoulder Rotation
# 59--->Lying Dumbbell Internal Shoulder Rotation
# 60--->Machine Lateral Raise
# 61--->Machine Shoulder Press
# 62--->Monkey Row
# 63--->Overhead Press
# 64--->Plate Front Raise
# 65--->Power Jerk
# 66--->Push Press
# 67--->Reverse Cable Flyes
# 68--->Reverse Dumbbell Flyes
# 69--->Reverse Machine Fly
# 70--->Seated Dumbbell Shoulder Press
# 71--->Seated Barbell Overhead Press
# 72--->Seated Smith Machine Shoulder Press
# 73--->Snatch Grip Behind the Neck Press
# 74--->Squat Jerk
# 75--->Split Jerk
# 76--->Barbell Curl
# 77--->Barbell Preacher Curl
# 78--->Bayesian Curl
# 79--->Bodyweight Curl
# 80--->Cable Crossover Bicep Curl
# 81--->Cable Curl With Bar
# 82--->Cable Curl With Rope
# 83--->Concentration Curl
# 84--->Drag Curl
# 85--->Dumbbell Curl
# 86--->Dumbbell Preacher Curl
# 87--->Hammer Curl
# 88--->Incline Dumbbell Curl
# 89--->Machine Bicep Curl
# 90--->Resistance Band Curl
# 91--->Spider Curl
# 92--->Barbell Standing Triceps Extension
# 93--->Barbell Lying Triceps Extension
# 94--->Bench Dip
# 95--->Crossbody Cable Triceps Extension
# 96--->Close-Grip Push-Up
# 97--->Dumbbell Lying Triceps Extension
# 98--->Dumbbell Standing Triceps Extension
# 99--->Overhead Cable Triceps Extension
# 100--->Tricep Bodyweight Extension
# 101--->Tricep Pushdown With Bar
# 102--->Tricep Pushdown With Rope
# 103--->Air Squat
# 104--->Barbell Hack Squat
# 105--->Barbell Lunge
# 106--->Barbell Walking Lunge
# 107--->Belt Squat
# 108--->Body Weight Lunge
# 109--->Bodyweight Leg Curl
# 110--->Box Jump
# 111--->Box Squat
# 112--->Bulgarian Split Squat
# 113--->Chair Squat
# 114--->Dumbbell Lunge
# 115--->Dumbbell Squat
# 116--->Front Squat
# 117--->Glute Ham Raise
# 118--->Goblet Squat
# 119--->Hack Squat Machine
# 120--->Half Air Squat
# 121--->Hip Adduction Machine
# 122--->Jumping Lunge
# 123--->Landmine Hack Squat
# 124--->Landmine Squat
# 125--->Leg Curl On Ball
# 126--->Leg Extension
# 127--->Leg Press
# 128--->Lying Leg Curl
# 129--->Nordic Hamstring Eccentric
# 130--->Pause Squat
# 131--->Pistol Squat
# 132--->Reverse Barbell Lunge
# 133--->Romanian Deadlift
# 134--->Safety Bar Squat
# 135--->Seated Leg Curl
# 136--->Shallow Body Weight Lunge
# 137--->Side Lunges (Bodyweight)
# 138--->Smith Machine Bulgarian Split Squat
# 139--->Smith Machine Front Squat
# 140--->Smith Machine Squat
# 141--->Squat
# 142--->Step Up
# 143--->Zercher Squat
# 144--->Zombie Squat
# 145--->Assisted Chin-Up
# 146--->Assisted Pull-Up
# 147--->Back Extension
# 148--->Banded Muscle-Up
# 149--->Barbell Row
# 150--->Barbell Shrug
# 151--->Block Clean
# 152--->Block Snatch
# 153--->Cable Close Grip Seated Row
# 154--->Cable Wide Grip Seated Row
# 155--->Chest to Bar
# 156--->Chin-Up
# 157--->Clean
# 158--->Clean and Jerk
# 159--->Deadlift
# 160--->Deficit Deadlift
# 161--->Dumbbell Deadlift
# 162--->Dumbbell Row
# 163--->Dumbbell Shrug
# 164--->Floor Back Extension
# 165--->Good Morning
# 166--->Gorilla Row
# 167--->Hang Clean
# 168--->Hang Power Clean
# 169--->Hang Power Snatch
# 170--->Hang Snatch
# 171--->Inverted Row
# 172--->Inverted Row with Underhand Grip
# 173--->Jefferson Curl
# 174--->Jumping Muscle-Up
# 175--->Kettlebell Swing
# 176--->Lat Pulldown With Pronated Grip
# 177--->Lat Pulldown With Supinated Grip
# 178--->Muscle-Up (Bar)
# 179--->Muscle-Up (Rings)
# 180--->One-Handed Cable Row
# 181--->One-Handed Lat Pulldown
# 182--->Pause Deadlift
# 183--->Pendlay Row
# 184--->Power Clean
# 185--->Power Snatch
# 186--->Pull-Up
# 187--->Pull-Up With a Neutral Grip
# 188--->Rack Pull
# 189--->Ring Pull-Up
# 190--->Ring Row
# 191--->Scap Pull-Up
# 192--->Seal Row
# 193--->Seated Machine Row
# 194--->Single Leg Deadlift with Kettlebell
# 195--->Smith Machine One-Handed Row
# 196--->Snatch
# 197--->Snatch Grip Deadlift
# 198--->Stiff-Legged Deadlift
# 199--->Straight Arm Lat Pulldown
# 200--->Sumo Deadlift
# 201--->T-Bar Row
# 202--->Trap Bar Deadlift With High Handles
# 203--->Trap Bar Deadlift With Low Handles
# 204--->Banded Side Kicks
# 205--->Cable Pull Through
# 206--->Clamshells
# 207--->Cossack Squat
# 208--->Death March with Dumbbells
# 209--->Donkey Kicks
# 210--->Dumbbell Romanian Deadlift
# 211--->Dumbbell Frog Pumps
# 212--->Fire Hydrants
# 213--->Frog Pumps
# 214--->Glute Bridge
# 215--->Hip Abduction Against Band
# 216--->Hip Abduction Machine
# 217--->Hip Thrust
# 218--->Hip Thrust Machine
# 219--->Hip Thrust With Band Around Knees
# 220--->Lateral Walk With Band
# 221--->Machine Glute Kickbacks
# 222--->One-Legged Glute Bridge
# 223--->One-Legged Hip Thrust
# 224--->Reverse Hyperextension
# 225--->Romanian Deadlift
# 226--->Smith Machine Hip Thrust
# 227--->Single Leg Romanian Deadlift
# 228--->Standing Glute Kickback in Machine
# 229--->Step Up
# 230--->Ball Slams
# 231--->Cable Crunch
# 232--->Crunch
# 233--->Dead Bug
# 234--->Dragon Flag
# 235--->Hanging Knee Raise
# 236--->Hanging Leg Raise
# 237--->Hanging Sit-Up
# 238--->Hanging Windshield Wiper
# 239--->High to Low Wood Chop with Band
# 240--->Horizontal Wood Chop with Band
# 241--->Jackknife Sit-Up
# 242--->Kneeling Ab Wheel Roll-Out
# 243--->Kneeling Plank
# 244--->Kneeling Side Plank
# 245--->Lying Leg Raise
# 246--->Lying Windshield Wiper
# 247--->Lying Windshield Wiper with Bent Knees
# 248--->Machine Crunch
# 249--->Mountain Climbers
# 250--->Oblique Crunch
# 251--->Oblique Sit-Up
# 252--->Plank
# 253--->Plank with Leg Lifts
# 254--->Russian Twist
# 255--->Side Plank
# 256--->Sit-Up
# 257--->Barbell Standing Calf Raise
# 258--->Donkey Calf Raise
# 259--->Eccentric Heel Drop
# 260--->Heel Raise
# 261--->Seated Calf Raise
# 262--->Standing Calf Raise
# 263--->Barbell Wrist Curl
# 264--->Barbell Wrist Curl Behind the Back
# 265--->Bar Hang
# 266--->Dumbbell Wrist Curl
# 267--->Farmers Walk
# 268--->Fat Bar Deadlift
# 269--->Gripper
# 270--->One-Handed Bar Hang
# 271--->Plate Pinch
# 272--->Plate Wrist Curl
# 273--->Towel Pull-Up
# 274--->Wrist Roller
# 275--->Barbell Wrist Extension
# 276--->Dumbbell Wrist Extension
# 277--->Rowing Machine
# 278--->Stationary Bike
# 279--->Bench Press
# 280--->Incline Dumbbell Press
# 281--->Bar Dips
# 282--->Standing Cable Chest Fly
# 283--->Overhead Press
# 284--->Seated Dumbbell Shoulder Press
# 285--->Dumbbell Lateral Raise
# 286--->Reverse Dumbbell Fly
# 287--->Deadlift
# 288--->Lat Pulldown
# 289--->Pull-Up
# 290--->Barbell Row
# 291--->Dumbbell Row
# 292--->Barbell Curl
# 293--->Dumbbell Curl
# 294--->Hammer Curl
# 295--->Barbell Lying Triceps Extension
# 296--->Overhead Cable Triceps Extension
# 297--->Tricep Pushdown
# 298--->Close-Grip Bench Press
# 299--->Squat
# 300--->Hack Squats
# 301--->Leg Extension
# 302--->Bulgarian Split Squat
# 303--->Seated Leg Curl
# 304--->Lying Leg Curl
# 305--->Romanian Deadlift
# 306--->Squat
# 307--->Hip Thrust
# 308--->Romanian Deadlift
# 309--->Bulgarian Split Squat
# 310--->Cable Crunch
# 311--->Hanging Leg Raise
# 312--->High to Low Wood Chop
# 313--->Crunch
# 314--->Standing Calf Raise
# 315--->Seated Calf Raise

# %%
with open('exercise_range.json', 'r') as f:
    exercise_data = json.load(f)

for k,v in exercise_data.items():
    for inner_key,value in v["exercise_weights"].items():
        # Round to 1 decimal place for cleaner numbers
        exercise_data[k]["exercise_weights"][inner_key]['min'] = round(0.4535 * value['min'], 0)
        exercise_data[k]["exercise_weights"][inner_key]['max'] = round(0.4535 * value['max'], 0)

# Save exercise_data instead of existing_data
with open('exercise_range_kg.json', 'w') as f:
    json.dump(exercise_data, f, indent=4)
